# %% [markdown]
# <a href="https://colab.research.google.com/github/Mudasir32k/Learning-Python/blob/Practice1/csvPracticeProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
import os

filename = "student.csv"

def add_student(Name, Age, Marks):
    file_exists = os.path.exists(filename)
    with open(filename, 'a', newline='') as file:
        writer = csv.writer(file)
        if not file_exists:
            writer.writerow(['Name', 'Age', 'Marks'])
        writer.writerow([Name, Age, Marks])

def show_students():
    with open(filename, 'r') as file:
        reader = csv.reader(file)
        next(reader)
        print('students record:')
        print('-' * 30)
        for row in reader:
            print(f'Name: {row[0]}, Age: {row[1]}, Marks: {row[2]}')
        print('-' * 30)

add_student('her', 34, 85)
add_student('anika', 33, 94)
show_students()
# Out:
# students record:
# ------------------------------
# Name: her, Age: 34, Marks: 85
# Name: anika, Age: 33, Marks: 94
# ------------------------------
